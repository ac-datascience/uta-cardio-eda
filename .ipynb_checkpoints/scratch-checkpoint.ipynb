# %%
source("cardio.project.source.R")

# %%
cardio <- process_data()

# %%
head(cardio)
# Out:
#   Product Age Gender Education MaritalStatus Usage Fitness Income Miles
# 1 TM195   18  Male   14        Male          3     4       29562  112
# 2 TM195   19  Male   15        Male          2     3       31836   75
# 3 TM195   19  Female 14        Female        4     3       30699   66
# 4 TM195   19  Male   12        Male          3     3       32973   85
# 5 TM195   20  Male   13        Male          4     2       35247   47
# 6 TM195   20  Female 14        Female        3     3       32973   66
#   IncomeGroup AgeGroup
# 1 [20-30k)    (17,19]
# 2 [30-45k)    (17,19]
# 3 [30-45k)    (17,19]
# 4 [30-45k)    (17,19]
# 5 [30-45k)    (19,25]
# 6 [30-45k)    (19,25]

# %%
summary(cardio)
# Out:
#   Product        Age           Gender      Education     MaritalStatus
#  TM195:80   Min.   :18.00   Female: 76   Min.   :12.00   Female: 76
#  TM498:60   1st Qu.:24.00   Male  :104   1st Qu.:14.00   Male  :104
#  TM798:40   Median :26.00                Median :16.00
#             Mean   :28.79                Mean   :15.57
#             3rd Qu.:33.00                3rd Qu.:16.00
#             Max.   :50.00                Max.   :21.00
#      Usage          Fitness          Income           Miles
#  Min.   :2.000   Min.   :1.000   Min.   : 29562   Min.   : 21.0
#  1st Qu.:3.000   1st Qu.:3.000   1st Qu.: 44059   1st Qu.: 66.0
#  Median :3.000   Median :3.000   Median : 50596   Median : 94.0
#  Mean   :3.456   Mean   :3.311   Mean   : 53720   Mean   :103.2
#  3rd Qu.:4.000   3rd Qu.:4.000   3rd Qu.: 58668   3rd Qu.:114.8
#  Max.   :7.000   Max.   :5.000   Max.   :104581   Max.   :360.0
#      IncomeGroup    AgeGroup
#  [20-30k)  : 1   (17,19]: 5
#  [30-45k)  :48   (19,25]:74
# ...

# %%
max.temp = c(23,32,12,100,43,32,9,29)    # a vector used for plotting
par(mfrow=c(1,2))    # set the plotting area into a 1*2 array
barplot(max.temp, main="Barplot")
pie(max.temp, main="Piechart", radius=1)
# Out:
# Plot with title “Piechart”
