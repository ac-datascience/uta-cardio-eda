# %% [markdown]
# # Import Data

# %%
source("cardio.project.source.R")

# %%
cardio <- process_data()

# %%
head(cardio)
# Out:
#   Product Age Gender Education MaritalStatus Usage Fitness Income Miles
# 1 TM195   18  Male   14        Male          3     4       29562  112
# 2 TM195   19  Male   15        Male          2     3       31836   75
# 3 TM195   19  Female 14        Female        4     3       30699   66
# 4 TM195   19  Male   12        Male          3     3       32973   85
# 5 TM195   20  Male   13        Male          4     2       35247   47
# 6 TM195   20  Female 14        Female        3     3       32973   66
#   IncomeGroup AgeGroup EducationGroup
# 1 [20-30k)    (17,19]  Some College
# 2 [30-45k)    (17,19]  Some College
# 3 [30-45k)    (17,19]  Some College
# 4 [30-45k)    (17,19]  High School
# 5 [30-45k)    (19,25]  Some College
# 6 [30-45k)    (19,25]  Some College

# %% [markdown]
# # Customer Profile`

# %% [markdown]
# ## Product by Group

# %%
options(repr.plot.width=20, repr.plot.height=5)
customer_profile_plots()
# Out:
# plot without title

# %% [markdown]
# ## Group by Product
